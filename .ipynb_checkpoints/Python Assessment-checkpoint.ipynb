# %%
#Simplified TaskTracking System
class Task:
    def __init__(self, task_name,due_date):
        self.task_name =task_name
        self.due_date=due_date
class TaskTracker:
    def __init__(self):
        self.tasks = []
    def add_task(self,task):
        self.tasks.append(task)
    def display_tasks(self):
        for task in self.tasks:
            print(f"Task Name: {task.task_name}, Due Date: {task.due_date}")
            
task_tracker = TaskTracker()
task1=task_tracker.add_task(Task("Submission",10))
task2=task_tracker.add_task(Task("Data Analysis",9))
task_tracker.display_tasks()
# Out:
# Task Name: Submission, Due Date: 10
# Task Name: Data Analysis, Due Date: 9

# %%
#Inventory Mangement
class Product:
    def __init__(self,product_id,name,price):
        self.product_id=product_id
        self.name=name
        self.price=price
class Inventory:
    def __init__(self):
        self.inventory=[]
    def add_product(self,product):
        self.inventory.append(product)
    def display_inventory(self):
        for p in self.inventory:
            print(f'Product_id:{p.product_id},Name: {p.name},Price:{p.price}')
inventory=Inventory()
inventory.add_product(Product(89,'soap',67))
inventory.display_inventory()
# Out:
# Product_id:89,Name: soap,Price:67

# %%
#Fibonaaci Series
def Fibonacci(n):
    fib=[]
    a,b=0,1
    count=0
    while count<n:
        fib.append(a)
        a,b=b,a+b
        count+=1
    return fib
            
def get_input():
    while True:
        try:
            n=int(input("Enter the no of Fibonacci terms"))
            if n<=0:
                print("Enter +ve int")
            else:
                return n
        except ValueError:
            print("Invalid Input")
            
def display_fibonacci_sequence(fib):
    print("Fibonacci series")
    for i in fib:
        print(i,end=" ")        
n=get_input()
fiboo=Fibonacci(n)
display_fibonacci_sequence(fiboo)
# Out:
# Enter the no of Fibonacci terms5
# Fibonacci series
# 0 1 1 2 3

# %%
class Book:
    def __init__(self, title, author, available_copies):
        self.title = title
        self.author = author
        self.available_copies = available_copies
        self.total_copies = available_copies

    def borrow(self, num_copies):
        if num_copies <= 0:#3
            print("Error: Please borrow at least one copy.")
            return
        if num_copies <= self.available_copies:
            self.available_copies -= num_copies#2
            print(f"{num_copies} copies of '{self.title}' borrowed successfully.")
        else:
            print(f"Error: Only {self.available_copies} copies of '{self.title}' available.")

    def return_book(self, num_copies):#2
        if num_copies <= 0:
            print("Error: Please return at least one copy.")
            return
        if num_copies <= self.total_copies - self.available_copies:
            self.available_copies += num_copies#2+2
            print(f"{num_copies} copies of '{self.title}' returned successfully.")
        else:
            print("Error: Invalid return quantity.")

    def display_info(self):
        print("Book Information:")
        print(f"Title: {self.title}")
        print(f"Author: {self.author}")
        print(f"Available Copies: {self.available_copies}/{self.total_copies}")

# Main program
book1 = Book("Python Programming", "John Smith", 5)
book1.display_info()
book1.borrow(3)
book1.display_info()
book1.return_book(2)
book1.display_info()
book1.return_book(6)  # Invalid return
book1.borrow(0)       # Invalid borrow
book1.borrow(10)      # Invalid borrow
# Out:
# Book Information:
# Title: Python Programming
# Author: John Smith
# Available Copies: 5/5
# 3 copies of 'Python Programming' borrowed successfully.
# Book Information:
# Title: Python Programming
# Author: John Smith
# Available Copies: 2/5
# 2 copies of 'Python Programming' returned successfully.
# Book Information:
# Title: Python Programming
# Author: John Smith
# Available Copies: 4/5
# Error: Invalid return quantity.
# Error: Please borrow at least one copy.
# Error: Only 4 copies of 'Python Programming' available.

# %%
class Product:
    def __init__(self, name, price, stock_quantity):
        self.name = name
        self.price = price
        self.stock_quantity = stock_quantity

    def purchase(self, quantity):
        if quantity <= 0:
            print("Error: Please purchase at least one item.")
            return
        if quantity <= self.stock_quantity:
            self.stock_quantity -= quantity
            print(f"Purchased {quantity} {self.name}(s) for ${self.price * quantity:.2f}.")
        else:
            print(f"Error: Only {self.stock_quantity} {self.name}(s) available.")

    def display_info(self):
        print("Product Information:")
        print(f"Name: {self.name}")
        print(f"Price: ${self.price:.2f}")
        print(f"Stock Quantity: {self.stock_quantity}")

class ShoppingCart:
    def __init__(self):
        self.items = []

   
    def add_item(self, product, quantity):
        if quantity <= 0:
            print("Error: Please add at least one item.")
            return
        if quantity>product.stock_quantity:
            print(f"Error: Only {product.stock_quantity} {product.name}(s) available.")
            return
        self.items.append((product, quantity))
        print(f"Added {quantity} {product.name}(s) to the cart.")


    def checkout(self):
        total_price = 0
        print("Shopping Cart:")
        for product, quantity in self.items:
            if quantity <= product.stock_quantity:
                total_price += product.price * quantity
                print(f"{product.name}: {quantity} @ ${product.price:.2f} each")
                product.stock_quantity -= quantity
            else:
                print(f"Error: Not enough stock for {product.name}.")
        print(f"Total Price: ${total_price:.2f}")
        self.items = []

# Main program
product1 = Product("Laptop", 999.99, 5)
product2 = Product("Headphones", 49.99, 10)
cart = ShoppingCart()

product1.display_info()
product2.display_info()
cart.add_item(product1, 2)
cart.add_item(product2, 12)  # Invalid add
cart.add_item(product1, -1)  # Invalid add
cart.checkout()
product1.display_info()
product2.display_info()

product1.purchase(10)  # Invalid purchase
cart.add_item(product1, 3)
cart.checkout()
# Out:
# Product Information:
# Name: Laptop
# Price: $999.99
# Stock Quantity: 5
# Product Information:
# Name: Headphones
# Price: $49.99
# Stock Quantity: 10
# Added 2 Laptop(s) to the cart.
# Error: Only 10 Headphones(s) available.
# Error: Please add at least one item.
# Shopping Cart:
# Laptop: 2 @ $999.99 each
# Total Price: $1999.98
# Product Information:
# Name: Laptop
# Price: $999.99
# Stock Quantity: 3
# Product Information:
# Name: Headphones
# Price: $49.99
# Stock Quantity: 10
# Error: Only 3 Laptop(s) available.
# Added 3 Laptop(s) to the cart.
# Shopping Cart:
# Laptop: 3 @ $999.99 each
# Total Price: $2999.97
