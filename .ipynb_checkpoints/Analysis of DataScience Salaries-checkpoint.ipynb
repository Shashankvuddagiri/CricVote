# %%
pwd
# Out:
# 'C:\\Users\\asritha'

# %% [markdown]
# # importing libraries

# %%
import pandas as pd

# %%
df=pd.read_csv("dssalaries1.csv")
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0        2023.0               SE              FT  Principal Data Scientist
# 1        2023.0               MI              CT               ML Engineer
# 2        2023.0               MI              CT               ML Engineer
# 3        2023.0               SE              FT            Data Scientist
# 4        2023.0               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750     2020.0               SE              FT            Data Scientist
# 3751     2021.0               MI              FT  Principal Data Scientist
# 3752     2020.0               EN              FT            Data Scientist
# 3753     2020.0               EN              CT     Business Data Analyst
# 3754     2021.0               SE              FT      Data Science Manager
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (3755, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3729 non-null   float64
#  1   experience_level    3755 non-null   object
#  2   employment_type     3755 non-null   object
#  3   job_title           3755 non-null   object
#  4   salary              3755 non-null   int64
#  5   salary_currency     3755 non-null   object
#  6   salary_in_usd       3755 non-null   int64
#  7   employee_residence  3755 non-null   object
#  8   remote_ratio        3746 non-null   float64
#  9   company_location    3755 non-null   object
#  10  company_size        3755 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 322.8+ KB

# %%
df.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  3729.000000  3.755000e+03    3755.000000   3746.000000
# mean   2022.369268  1.906956e+05  137570.389880     46.235985
# std       0.691867  6.716765e+05   63055.625278     48.590074
# min    2020.000000  6.000000e+03    5132.000000      0.000000
# 25%    2022.000000  1.000000e+05   95000.000000      0.000000
# 50%    2022.000000  1.380000e+05  135000.000000      0.000000
# 75%    2023.000000  1.800000e+05  175000.000000    100.000000
# max    2023.000000  3.040000e+07  450000.000000    100.000000

# %%
df.head(20)
# Out:
#     work_year experience_level employment_type                 job_title  \
# 0      2023.0               SE              FT  Principal Data Scientist
# 1      2023.0               MI              CT               ML Engineer
# 2      2023.0               MI              CT               ML Engineer
# 3      2023.0               SE              FT            Data Scientist
# 4      2023.0               SE              FT            Data Scientist
# 5         NaN               SE              FT         Applied Scientist
# 6      2023.0               SE              FT         Applied Scientist
# 7      2023.0               SE              FT            Data Scientist
# 8      2023.0               SE              FT            Data Scientist
# 9      2023.0               SE              FT            Data Scientist
# 10     2023.0               SE              FT            Data Scientist
# 11     2023.0               SE              FT              Data Analyst
# ...

# %%
df.tail(60)
# Out:
#       work_year experience_level employment_type  \
# 3695     2021.0               SE              FT
# 3696     2021.0               MI              FL
# 3697     2020.0               EX              FT
# 3698     2021.0               SE              FT
# 3699     2020.0               EN              FT
# 3700     2021.0               MI              FT
# 3701     2021.0               SE              FT
# 3702     2021.0               MI              FT
# 3703     2021.0               MI              FT
# 3704     2021.0               SE              FT
# 3705     2021.0               EN              FT
# 3706     2020.0               MI              FT
# 3707     2021.0               SE              FT
# 3708     2020.0               EN              FT
# 3709     2021.0               MI              FT
# 3710     2020.0               EN              PT
# 3711     2020.0               MI              FT
# 3712     2021.0               SE              FT
# ...

# %%
df[df.job_title=="Data "]
